# %%
data = {
    'email': 'smk@gmail.com',
    'username': 'smk',
    'password': 'smk4305s'
}
# Out:
#   Cell In[5], line 6
#     **data
#     ^
# SyntaxError: invalid syntax

# %%
print(*data.items())
# Out:
# ('email', 'smk@gmail.com') ('username', 'smk') ('password', 'smk4305s')
