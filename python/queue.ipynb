# %%
class Queue:

    def __init__(self):
        self.queue=[]

    def enqueue(self,item):
        return self.queue.append(item)

    def dequeue(self):
        return self.queue.pop(0)
    
    def size(self):
        return len(self.queue)
    
    def display(self):
        for i in self.queue:
            print([i])
    
Q1=Queue()
Q1.enqueue(1)
Q1.enqueue(2)
Q1.enqueue(3)
Q1.enqueue(4)
Q1.enqueue(5)
Q1.dequeue()
Q1.display()
# Out:
# [2]
# [3]
# [4]
# [5]
